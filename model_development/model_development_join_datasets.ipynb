# %%
import pprint
import pathlib
import numpy as np
import pandas as pd

# %%
# set directory path data
syria_data_dir = pathlib.Path('/Users/adamstueckrath/Desktop/syria_data/')

# syria_events_csv file path
events_pre_processed_csv = syria_data_dir / 'model' / 'model_data' / 'events_pre_processed.csv'

# tweets_no_rts_csv file path
tweets_pre_processed_csv = syria_data_dir / 'model' / 'model_data' / 'tweets_pre_processed.csv'

results_csv = syria_data_dir / 'model' / 'model_data' / 'tweet_modelv11.csv'

# %%
def read_csv_data(df):
    """
    Reads two csv files (tweets and events) and 
    returns a pandas dataframe for each file
    """
    return pd.read_csv(df, header=0)

# %%
events_df = read_csv_data(events_pre_processed_csv)
tweets_df = read_csv_data(tweets_pre_processed_csv)
results_df = read_csv_data(results_csv)
# Out:
# /Users/adamstueckrath/.pyenv/versions/3.6.5/envs/syria-project-3.6.5/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3183: DtypeWarning: Columns (0,2,3,4,6,7,8,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   if (yield from self.run_code(code, result)):

# %%
def string_to_datetime(t_date):
    """
    Turns a datetime string like this: 
    '2017-07-06T18:34:37.000Z' 
    to a Python datetime object like this -> 2017-07-06 18:34:41
    """
    
    return pd.to_datetime(t_date).date()


def remove_tweets_filter(tweets_df, events_df, filter_amount=None):
    """
    Drops Nan values from the tweet_text_normalize column and 
    returns dataframe filtered or whole
    """
    tweets_df = tweets_df.dropna(subset=['tweet_text_normalize'])
    if filter_amount:
        tweets_df = tweets_df[:filter_amount]

    tweets_df['tweet_created_at'] = tweets_df['tweet_created_at'].apply(string_to_datetime)
    events_df['event_date'] = events_df['event_date'].apply(string_to_datetime)

    return tweets_df, events_df


def eval_dataframe(tweets_df, events_df):
    """
    Evaluates dataframe column saved as string format 
    into a python list object
    """
    tweets_df['tweet_text_normalize'] = tweets_df['tweet_text_normalize'].apply(eval)
    events_df['event_text_normalize'] = events_df['event_text_normalize'].apply(eval)

    return tweets_df, events_df

# %%
tweets_df, events_df= remove_tweets_filter(tweets_df, events_df) 
tweets_df, events_df = eval_dataframe(tweets_df, events_df)
results_df.shape
# Out:
# /Users/adamstueckrath/.pyenv/versions/3.6.5/envs/syria-project-3.6.5/lib/python3.6/site-packages/ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# (638032, 3)

# %%
print('tweets subset {} events subset {}'.format(tweets_df.shape, events_df.shape))
# Out:
# tweets subset (638032, 13) events subset (2237, 14)

# %%
tweets_df_subset = tweets_df.drop(['tweet_id_str','tweet_lang', 'user_id_str', 
                                       'user_name', 'tweet_text_clean', 'tweet_text_tokenize'], axis=1)

events_df_subset = events_df.drop(['event_type', 'actor_1', 'assoc_actor_1', 
                                       'actor_2', 'assoc_actor_2', 'latitude', 
                                       'longitude', 'event_text_clean', 'event_text_tokenize'], axis=1 )

print('tweets subset {} events subset {}'.format(tweets_df_subset.shape, events_df_subset.shape))
# Out:
# tweets subset (638032, 7) events subset (2237, 5)

# %%
tweets_df_subset = tweets_df_subset.set_index('tweet_id')
cosine_results_df_tweet_idx = results_df.set_index('tweet_id')

# %%
# tweets_df_subset

# 638010  Does God Love Everybody? By HH #YounusAlGohar ...
# 638011  Without the cooperation of Jordan and Turkey, ...
# 638012  Please remember Rothschild &amp; Murdoch love ...
# 638013  The mind after #Qanda. That is a #Syria – #Putin…
# 638014  AL MAYADEEN: Russia plans Syria base near Isra...
# 638015  I'm at Damascus St in Kuwait City, Al Asimah h...
# 638016  @felixbowlardo it's that ❤️ v 🤓 issue again #h...
# 638017  Know Your History: ‘Same Arab Race’ in Syria a...
# 638018  #ISIS leaders begin forcibly conscripting Syri...
# 638019  https://t.co/QqUxXlBxoj\nFrom "to herself—in a...
# 638020  I'm at Damascus St in Kuwait City, Al Asimah h...
# 638021  @AIIAmericanGirI @BreitbartNews This is why Ru...
# 638022  #1 &amp; #4 = true ("whole world" is hyperbole...
# 638023  Infuriating. Pumping more money and more arms ...
# 638024  Oh god, this is just horrendous. Horrendous. h...
# 638025  @Fox61A "Syria Direct" spoke about it some tim...
# 638026  Sacha Baron Cohen &amp; Isla Fisher Donate $1m...
# 638027  Kabar Australia: Syria likely shot down U.S. d...
# 638028  Just posted a photo @ Baghdad, Iraq https://t....
# 638029  CONFIRMED: US has killed 624 civilians in Syri...
# 638030  @cjillian0709 @TheObamaphile @yashar Yeah caus...
# 638031  Finally, the #SDF, whose main enemy is Turkey,...
#
#        tweet_sentiment_compound  tweet_sentiment_score tweet_sentiment_label  \
# 0                           0.0                    0.0               neutral
# 1                       -0.4215                   -1.0              negative
# 2                       -0.2263                   -1.0              negative
# 3                       -0.4767                   -1.0              negative
# 4                        0.1531                    0.0               neutral
# 5                       -0.5423                   -1.0              negative
# 6                       -0.5423                   -1.0              negative
# 7                        0.3612                    1.0              positive
# 8                           0.0                    0.0               neutral
# 9                        0.7698                    1.0              positive
# 10                          0.0                    0.0               neutral
# 11                          0.0                    0.0               neutral
# 12                       0.5859                    1.0              positive
# 13                      -0.3818                   -1.0              negative
# 14                       0.7178                    1.0              positive
# 15                       -0.743                   -1.0              negative
# 16                       0.5719                    1.0              positive
# 17                      -0.7506                   -1.0              negative
# 18                          0.0                    0.0               neutral
# 19                          0.0                    0.0               neutral
# 20                      -0.3818                   -1.0              negative
# 21                      -0.4767                   -1.0              negative
# 22                          0.0                    0.0               neutral
# 23                      -0.8955                   -1.0              negative
# 24                          0.0                    0.0               neutral
# 25                          0.0                    0.0               neutral
# 26                       0.0772                    0.0               neutral
# 27                      -0.4215                   -1.0              negative
# 28                      -0.5859                   -1.0              negative
# 29                       -0.296                   -1.0              negative
# ...                         ...                    ...                   ...
# 638002                  -0.1779                    0.0               neutral
# 638003                      0.0                    0.0               neutral
# 638004                      0.0                    0.0               neutral
# 638005                      0.0                    0.0               neutral
# 638006                      0.0                    0.0               neutral
# 638007                      0.0                    0.0               neutral
# 638008                   0.7003                    1.0              positive
# 638009                  -0.6808                   -1.0              negative
# 638010                   0.8658                    1.0              positive
# 638011                   0.2263                    1.0              positive
# 638012                   0.8658                    1.0              positive
# 638013                      0.0                    0.0               neutral
# 638014                      0.0                    0.0               neutral
# 638015                      0.0                    0.0               neutral
# 638016                      0.0                    0.0               neutral
# 638017                      0.0                    0.0               neutral
# 638018                      0.0                    0.0               neutral
# 638019                      0.0                    0.0               neutral
# 638020                      0.0                    0.0               neutral
# 638021                      0.0                    0.0               neutral
# 638022                      0.0                    0.0               neutral
# 638023                  -0.5267                   -1.0              negative
# 638024                  -0.7579                   -1.0              negative
# 638025                      0.0                    0.0               neutral
# 638026                      0.0                    0.0               neutral
# 638027                   0.3182                    1.0              positive
# 638028                      0.0                    0.0               neutral
# 638029                  -0.6705                   -1.0              negative
# 638030                   0.6597                    1.0              positive
# 638031                  -0.5267                   -1.0              negative
#
#                                      tweet_text_normalize  event_id  \
# 0       [syria, libya, let, hear, excuse, 4, 3, 2, 1, go]      9026
# 1       [far, clueless, unlike, including, congress, a...     37182
# 2       [see, footage, g20, welcometohell, protest, ha...     26646
# 3       [global, inquiry, aim, report, syria, sarin, a...     40481
# 4       [bill, liked, trump, muh, holocaust, amp, russ...      9054
# 5       [pursuing, hard, truth, syria, v, western, med...     37185
# 6       [pursuing, hard, truth, syria, v, western, med...     37185
# 7       [maybe, tell, everyone, want, come, would, lik...      9026
# 8       [essence, someone, syria, board, raft, float, ...      9026
# 9       [much, revolution, r, anarchism, user, happy, ...     40483
# 10      [rex, tillerson, statement, calling, syria, st...     43988
# 11      [c, smith, wh, said, discus, syria, agenda, id...     40481
# 12                               [aleppo, amazing, place]     37180
# 13      [distraction, rogue, cia, stage, false, flag, ...      9054
# 14      [magameetups, maga, seymour, hersh, respected,...      9026
# 15                 [gross, violation, syria, sovereignty]      9026
# 16      [viewer, discretion, jonathan, pie, trigger, h...      9026
# 17      [illegal, u, invasion, syria, min, 1, 50, prot...      9026
# 18      [strip, citizenship, deport, maybe, syria, ira...      9026
# 19      [fracture, emerge, turkey, alliance, northern,...      9026
# 20      [russian, embassy, pushing, fakenews, battle, ...      9033
# 21      [global, inquiry, aim, report, syria, sarin, a...     40481
# 22      [u, outmaneuvers, syria, damascus, baghdad, hi...     37185
# 23      [hugely, ridiculous, 4, spectator, wimbledon, ...      9054
# 24                                [would, call, invasion]      9026
# 25             [tisl, umm, probably, latter, isil, syria]      9026
# 26      [ten, year, old, syrian, refugee, built, model...     37179
# 27      [trump, respond, assad, launch, attack, pls, r...     40481
# 28      [humanrights, g20, summit, trump, putin, meeti...     26648
# 29      [u, could, work, russia, syria, fly, zone, til...      9054
# ...                                                   ...       ...
# 638002  [amazing, time, mal, amp, amp, dempsey, young,...     10245
# 638003  [report, russia, plan, syria, base, near, isra...     10295
# 638004  [al, mayadeen, russia, plan, syria, base, near...     37575
# 638005  [report, russia, plan, syria, base, near, isra...     10295
# 638006  [report, russia, plan, syria, base, near, isra...     10295
# 638007  [report, russia, plan, syria, base, near, isra...     10295
# 638008                     [aleppo, hope, better, future]     10212
# 638009  [video, paralyse, eliminate, isi, le, 24, hour...     37601
# 638010  [god, love, everybody, hh, younusalgohar, syri...     10221
# 638011  [without, cooperation, jordan, turkey, cia, su...     10272
# 638012  [please, remember, rothschild, amp, murdoch, l...     10317
# 638013                        [mind, qanda, syria, putin]     27018
# 638014  [al, mayadeen, russia, plan, syria, base, near...     37575
# 638015           [damascus, st, kuwait, city, al, asimah]     10227
# 638016                          [v, issue, headneverwins]     10144
# 638017  [know, history, arab, race, syria, palestine, ...     10198
# 638018  [isi, leader, begin, forcibly, conscripting, s...     10215
# 638019                    [faux, guy, fawkes, mask, post]     10317
# 638020           [damascus, st, kuwait, city, al, asimah]     10227
# 638021  [russia, took, part, ukraine, crimea, unchalle...     27020
# 638022  [1, amp, 4, true, whole, world, hyperbole, ofc...     44085
# 638023  [infuriating, pumping, money, arm, opposition,...     26989
# 638024                  [oh, god, horrendous, horrendous]     10317
# 638025                  [syria, direct, spoke, time, ago]     27018
# 638026  [sacha, baron, cohen, amp, isla, fisher, donat...     27018
# 638027  [kabar, australia, syria, likely, shot, u, dro...     37575
# 638028                     [posted, photo, baghdad, iraq]     10118
# 638029       [confirmed, u, killed, 624, civilian, syria]     44084
# 638030  [yeah, cause, president, need, get, job, hand,...     10221
# 638031  [finally, sdf, whose, main, enemy, turkey, kno...     10127
#
#         cosine_value
# 0              0.000
# 1              0.082
# 2              0.096
# 3              0.097
# 4              0.011
# 5              0.109
# 6              0.109
# 7              0.000
# 8              0.000
# 9              0.108
# 10             0.116
# 11             0.047
# 12             0.174
# 13             0.013
# 14             0.000
# 15             0.000
# 16             0.000
# 17             0.000
# 18             0.000
# 19             0.000
# 20             0.039
# 21             0.101
# 22             0.108
# 23             0.166
# 24             0.000
# 25             0.000
# 26             0.125
# 27             0.061
# 28             0.104
# 29             0.017
# ...              ...
# 638002         0.053
# 638003         0.169
# 638004         0.162
# 638005         0.169
# 638006         0.169
# 638007         0.169
# 638008         0.088
# 638009         0.071
# 638010         0.019
# 638011         0.094
# 638012         0.000
# 638013         0.008
# 638014         0.136
# 638015         0.231
# 638016         0.211
# 638017         0.059
# 638018         0.122
# 638019         0.000
# 638020         0.231
# 638021         0.165
# 638022         0.127
# 638023         0.138
# 638024         0.000
# 638025         0.007
# 638026         0.002
# 638027         0.210
# 638028         0.059
# 638029         0.248
# 638030         0.073
# 638031         0.058
#
# [638032 rows x 9 columns]

# %%
results_df = pd.merge(results_df, events_df_subset, on='event_id', how='left')
results_df.shape
# Out:
# (638032, 13)

# %%
# results_df.tail()

# %%
* need to do validation on ending file with kmeans clustering and silloute coefient
- might need to drop nan or 0

# %%
test = results_df.dropna(subset=['cosine_value'])

# %%
test.shape
# Out:
# (633244, 13)
