# %%
import bs4
import googletrans
import requests
import pprint
import pandas
from urllib import parse
import twint

# %%
def extract_database_name(url):
    parse_url = parse.urlsplit(url).path
    path_url = parse_url.split('/')
    return path_url[3]

def add_url_page_number(url, page_number):
    parse_url = parse.urlsplit(url)
    
    # split url path
    path_url = parse_url.path.split('/')

    # remove and replace page number with page_number
    previous_number = path_url[4]
    path_url.remove(previous_number)
    path_url.insert(4, str(page_number))
    
    # join new_path and add it to the base url
    new_path = '/'.join( t for t in path_url)
    return parse.urljoin(url, new_path)

def vcd_crawl(url_path, total_pages):
    df_list = []
    for page_number in range(1, total_pages+1):
        
        # get url with correct page number
        url = add_url_page_number(url_path, page_number)
        page = requests.get(url)
        
        # logging new page number
        print("getting page{}".format(str(page_number)))
              
        # create a BeautifulSoup object
        soup = bs4.BeautifulSoup(page.text, "lxml")

        # find the table in the html with the class peopleListing
        table = soup.find("table", class_="peopleListing")

        # html to pandas dataframe
        df = pandas.read_html(str(table), header=0, index_col=None)
        
        df_list.append(df[0])
    
    final_df = pandas.concat(df_list)
    final_df.reset_index(drop=True, inplace=True)
    return final_df

def run_crawl(url_paths_pages):
    for url_path, total_pages in url_paths.items():
        dataset = vcd_crawl(url_path, total_pages)
        dataset.to_csv('~/Desktop/vdc_causality_{database_name}.csv'.format(database_name=extract_database_name(url_path)))

# maybe turn into dict  
url_paths = {
            "http://www.vdc-sy.info/index.php/en/martyrs/1/c29ydGJ5PWEua2lsbGVkX2RhdGV8c29ydGRpcj1ERVNDfGFwcHJvdmVkPXZpc2libGV8ZXh0cmFkaXNwbGF5PTB8":1667,
            "http://www.vdc-sy.info/index.php/en/detainees/1/c29ydGJ5PWEuaTN0ZXFhbF9kYXRlfHNvcnRkaXI9REVTQ3xhcHByb3ZlZD12aXNpYmxlfGV4dHJhZGlzcGxheT0wfA==":667,
            "http://www.vdc-sy.info/index.php/en/missing/1/c29ydGJ5PWEuZGlzYXBlYXJlZF9kYXRlfHNvcnRkaXI9REVTQ3xhcHByb3ZlZD12aXNpYmxlfGV4dHJhZGlzcGxheT0wfA==":30
            }

# %%
#test = pandas.read_csv('~/Desktop/vdc_causality_detainees.csv', header=0, index_col=0)

# %%
#print (test.iloc[35776])

# %%
c = twint.Config()
c.Geo = "36.2012400,37.1611700,5km"
c.Since = "2017-1-1"
c.Lang = "en"
# Custom output format
c.Store_csv = True
c.Custom_csv = ["id", "date", "user_id", "username", "tweet", "hashtags", "location"]
c.Output = "twitter.csv"

twint.run.Search(c)
# Out:
# 1037056459002073088 2018-09-04 14:15:02 CDT <mouneb_abo_taim> As the child in the shadow of the current war in the country and in the province of Aleppo controlled by the rebels need children in the sale of fruits and vegetables in that region…  https://www.instagram.com/p/BnUMh3PnURK/?utm_source=ig_twitter_share&igshid=ydar2z5f8o24 …
# 1020060090018168834 2018-07-19 16:37:31 CDT <radwan_so> ...ففي الصمت .. يختفي الكلام .. ويحل محله .. نظرات العيون .. تراقب .. تنتظر .. لترسم .. طريق ً الآمال .. وتعيد فتح .. بوابة الحياة .. لعلها تحظى .. بدفء .. يزيل برود صمت .. المكان ..…  https://www.instagram.com/p/BlbbS7Ynr0u/?utm_source=ig_twitter_share&igshid=18hppa8ir1pea …
# 1011164752557592578 2018-06-25 03:30:38 CDT <radwan_so> ...تتمرد الحروف وتفعل ما تريد وكانها تخفي كلمات تحت وسادة الحياة .. لم تنطق بها .. ولم ترضى البوح بها .. حتى يأتي يوم تخبر الدنيا .. بما كانت تكتم في تلك الاوقات .. .Radwan_so.#سوا…  https://www.instagram.com/p/BkcN29Vn3R1/?utm_source=ig_twitter_share&igshid=1bzov6v19kujv …
# 1009034276078342144 2018-06-19 06:24:53 CDT <9PPbzex5MhUSHuV> @DAWh5QuEgmv9L6A pic.twitter.com/ekRuhrmVfr
# 1006258472864886784 2018-06-11 14:34:49 CDT <epoddubny> Удивительные ощущения, когда возвращаешься в…  https://www.instagram.com/p/Bj5XOnwHKOF/?utm_source=ig_twitter_share&igshid=1nrl6bc9g91m …
# 987407165836156928 2018-04-20 14:06:28 CDT <Adeeb_Alsayed> The #oldest #inhabited #city in the #world #fine_art #photography #galaxy #edits #lightroom…  https://www.instagram.com/p/BhzapD2Hc46/
# 985690231163834368 2018-04-15 20:23:59 CDT <SAULOVALLEY> URGENTE - Caça não identificado acaba de bombardear uma base militar iraniana localizada na…  https://www.instagram.com/p/BhnM5lKHSga/
# 985103201077784576 2018-04-14 05:31:20 CDT <J_Pilibbossian> With the best @kh_kindahanna 😍😍😍 النظرة 😍💜💜💜💜💜…  https://www.instagram.com/p/BhjC7ZPnyhA3D2cDfGQ493XnrSmMTSVhhSlU5k0/ …
# 973644115903688704 2018-03-13 14:37:01 CDT <Adeeb_Alsayed> #Reconstruction #Life #will #return#syria #aleppo #communities #people #SyriaCrisis #life…  https://www.instagram.com/p/BgRn7__Aj3h/
# 972040651603759104 2018-03-09 03:25:25 CDT <YYuand> Boomsquads💣💣💣 @ Tekeyan Club  https://www.instagram.com/p/BgGOw_NHmmzQgHFWGRhq-WNmUirFgO-Hny2Ogg0/ …
# 970303153764814848 2018-03-04 08:21:13 CDT <taciomenaeu> 🇸🇾😥Ninguém vai fazer nada? É isso mesmo?🇸🇾😥#playforsiria em مدينة حلب Aleppo City  https://www.instagram.com/p/Bf54pQ3H1sX/
# 970024375897407488 2018-03-03 13:53:28 CDT <almuftah1972> لصفاء رسمك مساحات من النغمات تغوص في كنه الصفحات المسورة ولنقاء…  https://www.instagram.com/p/Bf353lgHBcsR94srHaV_SbBoLf9A4h789yOi880/ …
# 968640594498080769 2018-02-27 18:14:48 CDT <afshinrattansi> Lawrence of Arabia's unpaid bar tab at the Baron Hotel in Aleppo, Syria @ Baron Hotel  https://www.instagram.com/p/BfuEmiNAB4O/
# 964609060157952001 2018-02-16 15:14:56 CDT <obaid83alajme> الحمدلله كل شي بخير  و تو رجعنا المركز #اسد_المطافي#مطافي…  https://www.instagram.com/p/BfRbG4InQl4veFN3RRwObAMiVgB6p5zupveNSU0/ …
# 961502301423796224 2018-02-08 01:29:47 CDT <Adeeb_Alsayed> #Repost  http://qusai.al .yousef with instatoolsapp ・・・..#man #Aleppo #Syria #Hama #old_aleppo…  https://www.instagram.com/p/Be7WeccgfgX/
# 959803336399581184 2018-02-03 08:58:42 CDT <Rasha_ak> قلعة حلب #الحب #الجمال #حلب #live #love #picoftheday #sun @ Citadel of Aleppo  https://www.instagram.com/p/BevR4LCB884/
# 958231821824774145 2018-01-30 00:54:04 CDT <mikelayestaran> Interior de la fortaleza de Alepo, de nuevo abierta al público. en Citadel of Aleppo  https://www.instagram.com/p/BekHPeQgxTO/
# 957249776751468545 2018-01-27 07:51:46 CDT <Rasha_ak> A Peace of Art #aleppo #syria #tree #beauty #live #pictureperfect #sky #clouds #picoftheday…  https://www.instagram.com/p/BedIqDdhWy0/
# 956980056387215360 2018-01-26 13:59:59 CDT <mikelayestaran> Ciudadela de Alepo, abierta de nuevo al público en Citadel of Aleppo  https://www.instagram.com/p/BebOACvAc1p/
# 949720028143915008 2018-01-06 13:11:14 CDT <GabrielAbdlNour> عندما يغلّفني آذان مدينة #حلب وأنا مفتتحا سنة ٢٠١٨ من أعلى نقطة في قلعتها... #aleppo #alep…  https://www.instagram.com/p/BdnoArUB6yZ/
# 947583500152078336 2017-12-31 15:41:26 CDT <Durayd_Shekho> #happy_new_year @ الموكامبو Al-Mogambo  https://www.instagram.com/p/BdYc8PSBaR3xUsdMVz7tgM8nfMImSMwwdubVD00/ …
# 945978985636233216 2017-12-27 05:25:40 CDT <zsnassani> #zeus #aleppo #citadel #ancient #civilization #homeland #syria #syrianmodel #hulk #mensfashion…  https://www.instagram.com/p/BdNDSpnAR1N/
# 945250377682657280 2017-12-25 05:10:26 CDT <radwan_so> ***صباح الياسمين ... مع مطر كانون ... مع شوق التراب .. الذي ينتظر تساقط أزهار الياسمين ..…  https://www.instagram.com/p/BdHgWSkginW/
# 944614426954686465 2017-12-23 11:03:24 CDT <fateebas> Kutsal topraklardan bir anı.. @ Haleb, Halab, Syria  https://www.instagram.com/p/BdDWwqtl17TCE_-rMfB4GBnQe8dGCSClJ1GKXI0/ …
# 938072895116455936 2017-12-05 09:49:41 CDT <oozora_otenki> AleppoAleppo, Syria13.9°C | 57.0°FHumidity: 66%Clear Sky pic.twitter.com/EQ7UGCf3xF
# 936880875458854913 2017-12-02 02:53:01 CDT <waseemalsakhla> تفاصيل الحرب أصبحت جزءا من كل شيء ، حتى حملة تنظيف لمحيط قلعة حلب 😐…  https://www.instagram.com/p/BcMZ419DU_1gvCc-RZzH2DpEv81beZh8qM6tkg0/ …
# 936516096672354305 2017-12-01 02:43:31 CDT <bassel_khabbaz> I'm at Citadel Of Aleppo in Aleppo, Aleppo Governorate https://www.swarmapp.com/c/kq9hngOn0vF
# 936311977831317504 2017-11-30 13:12:26 CDT <kamilcatak> #aleppo #Emevi #mosque #Halep #Emevi #camii #light #perspective #shoot #documantry #cameraman…  https://www.instagram.com/p/BcIXPmyAO4b/
# 935533419366420480 2017-11-28 09:38:43 CDT <oozora_otenki> @__El_rulo AleppoAleppo, Syria11.9°C | 53.5°FHumidity: 88%Clear Sky pic.twitter.com/Qha6PYYdBo
# 935292617591611393 2017-11-27 17:41:51 CDT <Akbarrifaldi98> #acetamavest2017 @ Al-Kamal School  https://www.instagram.com/p/BcBHqL1lfoy/
# 935289895052103680 2017-11-27 17:31:02 CDT <Akbarrifaldi98> Teacher Day Acetamavest 2017 @ Al-Kamal School  https://www.instagram.com/p/BcBGdihFTYm/
# 935247721220382720 2017-11-27 14:43:27 CDT <salah_dada> كم مرة مشينا عهالطريئ و حجار و حفظت اساميناكم غنية و كم صديئ كانوا…  https://www.instagram.com/p/BcAzRy4Fk2P8xDdKPWhfKubF1hjC0UIPpr1XvM0/ …
# 932873050869108736 2017-11-21 01:27:21 CDT <oozora_otenki> @Ismael7798 AleppoAleppo, Syria12.2°C | 53.9°FHumidity: 98%Moderate Rain pic.twitter.com/QVDzUbFzUf
# 932709404817928192 2017-11-20 14:37:05 CDT <Rasha_ak> Old aleppo .. #sunset #aleppo #syria #life #picoftheday #حلب #الحب #الحياة #الجمال @ Citadel of…  https://www.instagram.com/p/Bbuw_aDHyBI/
# 930780489815818241 2017-11-15 06:52:16 CDT <mkjarrah64> فوزية .. وينها .. وينها !!!!!؟#shoukranmortaja9 #شكران_مرتجى #فوزية #محمد_خير_جراح #أبو_بدر…  https://www.instagram.com/p/BbhDPo4hloR/
# 930500953802985472 2017-11-14 12:21:29 CDT <mkjarrah64> قلعة حلب تاريخ و أم المدن شهبامن نور كونها رب السما .. شهباللضيف أهل الكرم .. بس عالعدا…  https://www.instagram.com/p/BbfEnAQB1ZG/
# 929406456805261312 2017-11-11 11:52:21 CDT <radwan_so> لا شيء جديد ... إلا أنني من هنا ... @ Citadel of Aleppo  https://www.instagram.com/p/BbXS-Y2AUe8/
# 929028049319817216 2017-11-10 10:48:42 CDT <radwan_so> #جامع_الأطروش #أمير_حلب #حلب #محيط_قلعة_حلب #القلعة Pic by @radwan_so Radwan_so @ Citadel of…  https://www.instagram.com/p/BbUdPzKguJR/
# 929025560214364161 2017-11-10 10:38:48 CDT <radwan_so> ...دع الحديث ل الحجارة ،،فهي الوحيدة التي تعرف ماذا حدث ،،هي الاصدق فهي كانت تتألم ،،عند…  https://www.instagram.com/p/BbUlxUkAbTc/
# 929018991921819651 2017-11-10 10:12:42 CDT <radwan_so> ...هنا يمضي الوقت مثقلا ً ب أعباء ماضي قديم ... أناس أتوا و رحلوا ولم يبقى منهم إلا ذكرى ....…  https://www.instagram.com/p/BbUiyDtgZn2/
# 929010547634462721 2017-11-10 09:39:09 CDT <radwan_so> #جامع_الأطروش #أمير_حلب #حلب #محيط_قلعة_حلب #القلعة Pic by @radwan_so Radwan_so @ Citadel of…  https://www.instagram.com/p/BbUdPzKguJR/
# 929009592352366592 2017-11-10 09:35:21 CDT <radwan_so> #لااله_الاالله_محمدرسول_الله#حلب #حلب_القديمة #خانات_حلبPic from @radwan_so Radwan_so @…  https://www.instagram.com/p/BbUeSUVASOF/
# 929005118502133760 2017-11-10 09:17:34 CDT <radwan_so> #الياسمين #جامع_الأطروش #أمير_حلب Pic by @radwan_soRadwan_so @ Citadel of Aleppo  https://www.instagram.com/p/BbUZxkTAZAx/
# 923259700233293825 2017-10-25 13:47:20 CDT <alraisi_halima> منها عيُون الخيل لامرت من الهيبه تغار ثقيلة الممشى وتجمْح لوتشوف ظِلالهآ ♥️ #سلامة علي❤️ @…  https://www.instagram.com/p/BarnwaqHlsd/
# 921409470483390466 2017-10-20 11:15:11 CDT <Adeeb_hawale> JCI SYRIA 9th national convention Aleppo 2017#JCI_syria #JCI #Aleppo #peac #citadel_of_aleppo…  https://www.instagram.com/p/BaeeCKtg_7A/
# 915932837320249345 2017-10-05 08:33:00 CDT <radwan_so> #yes_we_can #mtn #syria @ Aleppo Castle  https://www.instagram.com/p/BZ3j2wIgDAm/
# 914206205354135552 2017-09-30 14:11:59 CDT <waseemalsakhla> بالفرج يا رب 😃 @ ساعة باب الفرج  https://www.instagram.com/p/BZrStKtDEcfFqYhyrQTluo0g_ySdyxSsSDXJq40/ …
# 913140359764611079 2017-09-27 15:36:41 CDT <waseemalsakhla> الناس هنا في حلب يبحثون عن فرصة للاحتفال بمدينتهم 😍 @ Citadel of Aleppo  https://www.instagram.com/p/BZjuBAMhFuV7zlhfOB1A6iP5LAkkaUTJr3hGDo0/ …
# 906478169221419008 2017-09-09 06:23:31 CDT <oozora_otenki> @rnrlx AleppoAleppo, Syria36.7°C | 98.0°FHumidity: 26%Clear Sky pic.twitter.com/WkT1R1evxu
# 906152243426201600 2017-09-08 08:48:24 CDT <AhmadShafiBilal> وهربجي @ Show cafe  https://www.instagram.com/p/BYyEMLIABCFQGZ3p3iEQcXmEASo_MWy9211JQU0/ …
# 904016153416257536 2017-09-02 11:20:21 CDT <oozora_otenki> @CientificTxec AleppoAleppo, Syria35.1°C | 95.2°FHumidity: 25%Clear Sky pic.twitter.com/ops60qnjPf
# 893609582521659394 2017-08-04 18:08:21 CDT <oozora_otenki> @memscat AleppoAleppo, Syria19.7°C | 67.4°FHumidity: 88%Clear Sky pic.twitter.com/r4gIiMLey6
# 890195178434306048 2017-07-26 08:00:44 CDT <oozora_otenki> @__El_rulo AleppoAleppo, Syria38.2°C | 100.8°FHumidity: 25%Clear Sky pic.twitter.com/4GcjLnhBD6
# 889935559434653696 2017-07-25 14:49:06 CDT <radwan_so> Radwan_so @ Aleppo Castle  https://www.instagram.com/p/BW-1shiAmbU/
# 889935011800989700 2017-07-25 14:46:55 CDT <radwan_so> Radwan_so @ Aleppo Castle  https://www.instagram.com/p/BW-1cczgXHj/
# 887730811943997440 2017-07-19 12:48:13 CDT <oozora_otenki> @rnrlx AleppoAleppo, Syria28.1°C | 82.6°FHumidity: 37%Clear Sky pic.twitter.com/qUyLsMQfjZ
# 884886039734743040 2017-07-11 16:24:06 CDT <radwan_so> إحدى مقطوعات #موزارت #دعوة للتسامح والسلام #من_رماد_الحرب#حلب_تنبض…  https://www.instagram.com/p/BWa9cJBAFxYTjPFf8vwBPD1CrT19CxQvrC5F0o0/ …
# 884878424787099649 2017-07-11 15:53:51 CDT <radwan_so> #النشيد_السوري #من_رماد_الحرب #ساحة_فرحات Radwan_so @ ساحة فرحات  https://www.instagram.com/p/BWa5-g7AcT693jGGCZcFoYE_fHA4Z42vwIIHKs0/ …
# 884874011116810241 2017-07-11 15:36:19 CDT <radwan_so> #من_رماد_الحربRadwan_so @ ساحة فرحات  https://www.instagram.com/p/BWa3-MIgqRZvcv8fUyKoonQ1xw6W0lnoIFpzqQ0/ …
# 882025152082477056 2017-07-03 18:55:58 CDT <oozora_otenki> AleppoAleppo, Syria25.2°C | 77.4°FHumidity: 35%Clear Sky pic.twitter.com/W5ISFijKc3
# 881342998281412609 2017-07-01 21:45:20 CDT <oozora_otenki> AleppoAleppo, Syria23.1°C | 73.5°FHumidity: 34%Clear Sky pic.twitter.com/XZ6IekqXf8
# 877328923272646656 2017-06-20 19:54:49 CDT <alash119871> شاب بعد غياب اربع سنوات وبعد ما اشيع انه قد مات رجع الى اهله المحزن والمبكي ردة فعل ابوه يوم…  https://www.instagram.com/p/BVlQ3VMnecD/
# 877139841468837888 2017-06-20 07:23:29 CDT <oozora_otenki> @rnrlx AleppoAleppo, Syria28.6°C | 83.5°FHumidity: 38%Clear Sky pic.twitter.com/pQzdHrawab
# 875698387261288449 2017-06-16 07:55:39 CDT <oozora_otenki> @RuinedBread2 AleppoAleppo, Syria32.3°C | 90.1°FHumidity: 33%Clear Sky pic.twitter.com/VasXFxt8xm
# 875118045492125697 2017-06-14 17:29:35 CDT <oozora_otenki> AleppoAleppo, Syria20.0°C | 68.0°FHumidity: 60%Clear Sky pic.twitter.com/PHiDRdsTOJ
# 874166520720613377 2017-06-12 02:28:34 CDT <oozora_otenki> @usonai AleppoAleppo, Syria23.9°C | 74.9°FHumidity: 67%Clear Sky pic.twitter.com/sTBuZ2B7Ud
# 870774249727959041 2017-06-02 17:48:53 CDT <oozora_otenki> @rnrlx AleppoAleppo, Syria18.8°C | 65.9°FHumidity: 60%Clear Sky pic.twitter.com/7AfLlWpXs7
# 863361955905630209 2017-05-13 06:55:05 CDT <radwan_so> #halep_kalesi #aleppo_citadel #قلعة_حلب #taht_salonu #thorne_hall…  https://www.instagram.com/p/BUCBbDQA_b2JqLQ9u-ECajFENfnocp1MFTpAxE0/ …
# 862964868391030784 2017-05-12 04:37:12 CDT <oozora_otenki> @NaRuToUzUmEiKeR AleppoAleppo, Syria26.4°C | 79.5°FHumidity: 54%Clear Sky pic.twitter.com/Vx9XbLyWkG
# 862419233308856323 2017-05-10 16:29:02 CDT <oozora_otenki> @Erkas5 AleppoAleppo, Syria18.3°C | 64.9°FHumidity: 40%Clear Sky pic.twitter.com/Oquc0sQgos
# 856389915168342016 2017-04-24 01:10:41 CDT <lynx_shams> حلب يا ام الدنيا @ Citadel of Aleppo  https://www.instagram.com/p/BTQe54el8rM/
# 854392253522911232 2017-04-18 12:52:41 CDT <rozelisantos> Chore e reze por aleppo.Muitas crianças estão sofrendo 😥#aleppo #criancas #rezeporaleppo @…  https://www.instagram.com/p/BTCSeeLh2Hb/
# 851871972644573184 2017-04-11 13:57:59 CDT <SltCnmg> Viendo la foto de la Gran Mezquita de Alepo nos damos cuenta de que se habla mucho de los…  https://www.instagram.com/p/BSwYYrQA61a/
# 842969147202068480 2017-03-18 00:21:20 CDT <oozora_otenki> @usonai AleppoAleppo, Syria9.8°C | 49.7°FHumidity: 100%Light Rain pic.twitter.com/N0q0gmP41k
# 840290353051815936 2017-03-10 13:56:46 CDT <KbcSyria> غرفة تجارة حلب:يواصل المهرجان التاسع للمرأة والأسرة فعالياته لليوم الثاني في فندق شهباء حلب ..…  https://www.instagram.com/p/BReFq-llymU/
# 840288950375858176 2017-03-10 13:51:12 CDT <KbcSyria> Aleppo return @ Al Shahba-Aleppo Hotel  https://www.instagram.com/p/BReFCErljKg/
# 835091741250322437 2017-02-24 05:39:21 CDT <tsecontemporary> #tb (10 years ago) - Umayyad Mosque / Great Mosque of Aleppo-#aleppo #syria #10yearsago…  https://www.instagram.com/p/BQ5Jnl4DPRs/
# 834740007646670848 2017-02-23 06:21:41 CDT <tsecontemporary> #tbt (10 years ago) - Citadel of Aleppo-Apologies the last travel post was actually the…  https://www.instagram.com/p/BQ2pqytjr4a/
# 825502661789179904 2017-01-28 18:35:46 CDT <OconelR> Aleph..... essai 😩#painting #acrylicpainting @ Alep, Halab, Syria  https://www.instagram.com/p/BP1BAoWh9HG/
# 822453973500260352 2017-01-20 08:41:22 CDT <oozora_otenki> AleppoAleppo, Syria7.9°C | 46.2°FHumidity: 89%Scattered Clouds pic.twitter.com/FG50c9YuUk
# 822163050346254336 2017-01-19 13:25:20 CDT <oozora_otenki> @vlad_jango AleppoAleppo, Syria4.9°C | 40.8°FHumidity: 82%Clear Sky pic.twitter.com/FlzkXfl5CD
# 819076225440235520 2017-01-11 00:59:24 CDT <photosontheroad> Happy A seller of #Aleppo soap, happily showing the item on his shop.This happened before the…  https://www.instagram.com/p/BPHWmzfhxdn/
# 818976725547806720 2017-01-10 18:24:01 CDT <wasimoutri> It was a long ass night...It literally dragged till the next year @ Citadel of Aleppo  https://www.instagram.com/p/BPGpXAigzB3/
# 816432954079645696 2017-01-03 17:55:59 CDT <michael_father_> #Aleppo#aleppo_university I miss u ... 😔 @ Aleppo University  https://www.instagram.com/p/BO0klkgAdJ4/
